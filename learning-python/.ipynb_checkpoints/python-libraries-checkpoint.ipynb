# %%
import hashlib

help(hashlib)
# Out:
# Help on module hashlib:
#
# NAME
#     hashlib - hashlib module - A common interface to many hash functions.
#
# MODULE REFERENCE
#     https://docs.python.org/3.8/library/hashlib
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     new(name, data=b'', **kwargs) - returns a new hash object implementing the
#                                     given hash function; initializing the hash
#                                     using the given binary data.
#
#     Named constructor functions are also available, these are faster
#     than using new(name):
#
#     md5(), sha1(), sha224(), sha256(), sha384(), sha512(), blake2b(), blake2s(),
# ...

# %%
import codecs
md5 = hashlib.md5()
md5.update('do something.'.encode('ascii'))
bytes_obj = md5.digest()
hex_str= md5.hexdigest()

# %%
# type 'bytes' represents content with an escaped string, 
# under the hood the elements of types obj are integers range' 0-255.
print(type(bytes_obj), type(bytes_str[0]), len(bytes_str), bytes_str, bytes_str[0])

# the hex_str returned is really a string, in which every 2 chars represents
# the integer value of the byte in hexdecimal.
print(type(hex_str), type(hex_str[0]), len(hex_str), hex_str, hex_str[:2])

# convert a 'bytes' object to a list of integers, in which each integer represents 
# a byte with decimal integer value.
int_list = list(bytes_obj)
print(type(int_list), type(int_list[0]), len(int_list), int_list, int_list[0])

# convert a bytes object to a list of strings, each string represents 
# the value of a byte in hexdecimal
hex_str_repr_list = [ hex(b) for b in bytes_obj ]
print(type(hex_str_repr_list), type(hex_str_repr_list[0]), hex_str_repr_list, hex_str_repr_list[0])

# convert a hex-string-represented-element list to a list with corresponding integer element.
int_from_hex_repr = [ int(h, 16) for h in hex_str_repr_list ]
print(int_from_hex_repr)

# convert a bytes object represented in the form of escaped string to a string, in which
# every 2 chars represents the integer value of the corresponding byte of the bytes object in hexdecimal.
 
hex_bytes = codecs.encode(bytes_obj, 'hex') 
print(type(hex_bytes), hex_bytes, hex_bytes[1])

hex_string = hex_bytes.decode('utf-8')
print(hex_string)


hex_list = [hex(i) for i in int_list]
print(type(hex_list[0]),hex_list)
# Out:
# <class 'bytes'> <class 'int'> 16 b'`\x83x\x15\x05^c\x90\xaci\x8a(u%S\x81' 96
# <class 'str'> <class 'str'> 32 60837815055e6390ac698a2875255381 60
# <class 'list'> <class 'int'> 16 [96, 131, 120, 21, 5, 94, 99, 144, 172, 105, 138, 40, 117, 37, 83, 129] 96
# <class 'list'> <class 'str'> ['0x60', '0x83', '0x78', '0x15', '0x5', '0x5e', '0x63', '0x90', '0xac', '0x69', '0x8a', '0x28', '0x75', '0x25', '0x53', '0x81'] 0x60
# <class 'bytes'> b'60837815055e6390ac698a2875255381' 48
# 60837815055e6390ac698a2875255381
# <class 'str'> ['0x60', '0x83', '0x78', '0x15', '0x5', '0x5e', '0x63', '0x90', '0xac', '0x69', '0x8a', '0x28', '0x75', '0x25', '0x53', '0x81']

# %%
int('0x89', 16)
# Out:
# 137

# %%
list(b'\x60\x83x\x15\x05^c\x90\xaci\x8a(u%S\x81')
# [ `, \x83, x, \x15, \x05, ^, c, \x90, \xac, i, \x8a, (, u, %, S, \x81 ]
# Out:
# [96, 131, 120, 21, 5, 94, 99, 144, 172, 105, 138, 40, 117, 37, 83, 129]

# %%
h = [hex(i) for i in d]
i = [int(he, 16) for he in h]
i
# Out:
# [96, 131, 120, 21, 5, 94, 99, 144, 172, 105, 138, 40, 117, 37, 83, 129]

# %%
import heapq
help(heapq)
# Out:
# Help on module heapq:
#
# NAME
#     heapq - Heap queue algorithm (a.k.a. priority queue).
#
# MODULE REFERENCE
#     https://docs.python.org/3.8/library/heapq
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     Heaps are arrays for which a[k] <= a[2*k+1] and a[k] <= a[2*k+2] for
#     all k, counting elements from 0.  For the sake of comparison,
#     non-existing elements are considered to be infinite.  The interesting
#     property of a heap is that a[0] is always its smallest element.
#
#     Usage:
#
#     heap = []            # creates an empty heap
#     heappush(heap, item) # pushes a new item on the heap
#     item = heappop(heap) # pops the smallest item from the heap
# ...

# %%
 ' 000000000000001110101010101011101101010101010000'
['000000000000000101010101010101110110101000101000']
